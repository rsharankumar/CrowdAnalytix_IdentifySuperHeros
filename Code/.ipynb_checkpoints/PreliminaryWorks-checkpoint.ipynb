# %%
import pandas as pd
import os
import shutil
# Creating a train dataset file - holds all train img name and their label
f=open("C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/train_data.csv",'r+', newline='')
w=csv.writer(f)
# Get all the sub-folders and the files names using 2 loops
for root, directories, filenames in os.walk('C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Train'):
     for filename in filenames: 
             #print(os.path.join(filename))
             # writes the file names into a csv 
             w.writerow([filename])
#Save and close the file
f.close()

# %%
# Moving Files
for root, directories, filenames in os.walk('C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/CAX_Superhero_Train'):
         for filename in filenames: 
             #print(os.path.join(root,filename))
             src_image_path = os.path.join(root,filename)
             dest_image_path = 'C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Train'
             # Move all the training imags in sub-folders to train folder
             shutil.copy2(src_image_path, dest_image_path)

# %%
import csv
import pandas as pd
import os
import shutil
# Creating a test dataset file - holds all train img name and their label
f1=open("C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/test_data.csv",'r+', newline='')
w1=csv.writer(f1)
# Get all the sub-folders and the files names using 2 loops
for root, directories, filenames in os.walk('C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/CAX_Superhero_Test'):
     for filename1 in filenames: 
             print(os.path.join(filename1))
             # writes the file names into a csv 
             w1.writerow([filename1])
#Save and close the file
f1.close()
# Out:
# superhero_test_1.jpg
# superhero_test_10.jpg
# superhero_test_100.jpg
# superhero_test_1000.jpg
# superhero_test_1001.jpg
# superhero_test_1002.jpg
# superhero_test_1003.jpg
# superhero_test_1004.jpg
# superhero_test_1005.jpg
# superhero_test_1006.jpg
# superhero_test_1007.jpg
# superhero_test_1008.jpg
# superhero_test_1009.jpg
# superhero_test_101.jpg
# superhero_test_1010.jpg
# superhero_test_1011.jpg
# superhero_test_1012.jpg
# superhero_test_1013.jpg
# superhero_test_1014.jpg
# superhero_test_1015.jpg
# superhero_test_1016.jpg
# superhero_test_1017.jpg
# superhero_test_1018.jpg
# superhero_test_1019.jpg
# superhero_test_102.jpg
# superhero_test_1020.jpg
# superhero_test_1021.jpg
# superhero_test_1022.jpg
# superhero_test_1023.jpg
# superhero_test_1024.jpg
# superhero_test_1025.jpg
# superhero_test_1026.jpg
# superhero_test_1027.jpg
# superhero_test_1028.jpg
# superhero_test_1029.jpg
# superhero_test_103.jpg
# superhero_test_1030.jpg
# superhero_test_1031.jpg
# ...

# %%
# initial version - when train data were in separate folder
import pandas as pd
import os
import shutil
# Creating a train dataset file - holds all train img name and their label
#f=open("C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/train_data.csv",'r+', newline='')
#w=csv.writer(f)
# Get all the sub-folders and the files names using 2 loops
for root, directories, filenames in os.walk('C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train'):
     for filename in filenames: 
             print(os.path.join(root,filename))
             # writes the file names into a csv 
             #w.writerow([filename])
#Save and close the file
#f.close()
# Out:
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\.DS_Store
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\cax_antman_train1.jpg
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\cax_antman_train10.jpg
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\cax_antman_train100.jpg
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\cax_antman_train101.jpg
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\cax_antman_train102.jpg
# C:/Users/skumarravindran/Desktop/Kaggle/CrowdAnalytixIdentifySuperHeros/Old Files/CAX_Superhero_Train\Ant-Man\cax_antman_train103.jpeg
# ...
